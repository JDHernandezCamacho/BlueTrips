# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Datasets/Electric and Alternative Fuel Charging Stations.csv')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_17636\3514369627.py:1: DtypeWarning: Columns (6,16,20,31,33,36,39,40,41,43,46,52,53,55,57,58,60,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Datasets/Electric and Alternative Fuel Charging Stations.csv')

# %%
df
# Out:
#       Fuel Type Code                                  Station Name  \
# 0                CNG          Spire - Montgomery Operations Center
# 1                CNG                           PS Energy - Atlanta
# 2                CNG  Metropolitan Atlanta Rapid Transit Authority
# 3                CNG                         United Parcel Service
# 4                CNG                    Arkansas Oklahoma Gas Corp
# ...              ...                                           ...
# 70401           ELEC                     SCHLITZ PARK SCHLITZ PARK
# 70402           ELEC                          NEXUS EAST STATION 2
# 70403           ELEC                                       Raley's
# 70404           ELEC                           13601 Glenoaks blvd
# 70405           ELEC                            6723 Van Nuys blvd
#
#                Street Address  \
# 0            2951 Chestnut St
# 1            340 Whitehall St
# 2         2424 Piedmont Rd NE
# 3        270 Marvin Miller Dr
# ...

# %%
# Obtener el conteo de nulos por columna de df
null_count = df.isnull().sum()

# Obtener el porcentaje de nulos por columna
null_percentage = (df.isnull().mean()) * 100

# Crear un nuevo DataFrame con la información de conteo y porcentaje
null_info = pd.DataFrame({
    'Nulos': null_count,
    'Porcentaje': null_percentage
})

# Imprimir el nuevo DataFrame
print(null_info.sort_values('Nulos', ascending=False))
# Out:
#                               Nulos  Porcentaje
# Plus4                         70406  100.000000
# BD Blends (French)            70404   99.997159
# EV Other Info                 70357   99.930404
# LNG On-Site Renewable Source  70344   99.911939
# Hydrogen Status Link          70323   99.882112
# ...                             ...         ...
# ID                                0    0.000000
# Updated At                        0    0.000000
# Station Name                      0    0.000000
# Country                           0    0.000000
# Fuel Type Code                    0    0.000000
#
# [65 rows x 2 columns]

# %% [markdown]
# Filtrando por datos de vehiculos eléctricos

# %%
df = df[df['Fuel Type Code'] == 'ELEC']
df
# Out:
#       Fuel Type Code                     Station Name          Street Address  \
# 156             ELEC         LADWP - Truesdale Center      11797 Truesdale St
# 157             ELEC  LADWP - West LA District Office   1394 S Sepulveda Blvd
# 158             ELEC    Los Angeles Convention Center      1201 S Figueroa St
# 159             ELEC    LADWP - John Ferraro Building           111 N Hope St
# 160             ELEC       LADWP - Haynes Power Plant           6801 E 2nd St
# ...              ...                              ...                     ...
# 70401           ELEC        SCHLITZ PARK SCHLITZ PARK  1555 N River Center Dr
# 70402           ELEC             NEXUS EAST STATION 2        720 Airport Blvd
# 70403           ELEC                          Raley's   6119 Horseshoe Bar Rd
# 70404           ELEC              13601 Glenoaks blvd     13601 Glenoaks blvd
# 70405           ELEC               6723 Van Nuys blvd      6723 Van Nuys Blvd
#
# ...

# %% [markdown]
# Filtrando por Estado de Nueva york

# %%
df[df['State'] == 'NY']
# Out:
#       Fuel Type Code                                       Station Name  \
# 2087            ELEC  New York State Energy Research Development Aut...
# 2977            ELEC                   James J Peters VA Medical Center
# 3333            ELEC                                     Thruway Nissan
# 3334            ELEC                                     Thruway Nissan
# 3335            ELEC                               Country Club Imports
# ...              ...                                                ...
# 70266           ELEC                               GENESEO W PARK RIGHT
# 70267           ELEC                              GENESEO W PARK CENTER
# 70278           ELEC                           G & M REALTY 2 STATION 1
# 70288           ELEC                             40 N 4th St Apartments
# 70395           ELEC                                 EVolveNY Salamanca
#
#                      Street Address Intersection Directions       City State  \
# ...

# %%
def can_nulos():    
    # Obtener el conteo de nulos por columna de df
    null_count = df.isnull().sum()

    # Obtener el porcentaje de nulos por columna
    null_percentage = (df.isnull().mean()) * 100

    # Crear un nuevo DataFrame con la información de conteo y porcentaje
    null_info = pd.DataFrame({
        'Nulos': null_count,
        'Porcentaje': null_percentage
    })

    # Imprimir el nuevo DataFrame
    print(null_info.sort_values('Nulos', ascending=False))

# %%
print(can_nulos())
# Out:
#                               Nulos  Porcentaje
# LPG Primary                   60907       100.0
# E85 Other Ethanol Blends      60907       100.0
# LNG On-Site Renewable Source  60907       100.0
# Hydrogen Pressures            60907       100.0
# CNG Storage Capacity          60907       100.0
# ...                             ...         ...
# ID                                0         0.0
# Updated At                        0         0.0
# Station Name                      0         0.0
# Country                           0         0.0
# Fuel Type Code                    0         0.0
#
# [65 rows x 2 columns]
# None

# %% [markdown]
# Filtrando por Ciudad de Nueva York

# %%
df = df[df['City'] == 'New York']

# %%
df
# Out:
#       Fuel Type Code                               Station Name  \
# 7777            ELEC                Port Authority Bus Terminal
# 9645            ELEC                      United Parcel Service
# 14384           ELEC                                   Spectrum
# 14463           ELEC                 Central Parking - Tower 31
# 14669           ELEC                               Tribeca Park
# ...              ...                                        ...
# 69770           ELEC                             DOCK STATION 9
# 69771           ELEC                            DOCK STATION 10
# 69823           ELEC                      Lincoln Square Garage
# 69940           ELEC                              320 Mason Ave
# 70215           ELEC  Delancey & Essex Municipal Parking Garage
#
#           Street Address                            Intersection Directions  \
# 7777         625 8th Ave                                                NaN
# ...

# %%
can_nulos()
# Out:
#                               Nulos  Porcentaje
# LPG Nozzle Types                379       100.0
# NG Fill Type Code               379       100.0
# CNG Storage Capacity            379       100.0
# LPG Primary                     379       100.0
# LNG On-Site Renewable Source    379       100.0
# ...                             ...         ...
# Updated At                        0         0.0
# Station Name                      0         0.0
# EV Connector Types                0         0.0
# Country                           0         0.0
# Open Date                         0         0.0
#
# [65 rows x 2 columns]

# %% [markdown]
# Eliminando las columnas que tengan el 100 de los datos nulos

# %%
df = df.dropna(axis=1, how='all')
df
# Out:
#       Fuel Type Code                               Station Name  \
# 7777            ELEC                Port Authority Bus Terminal
# 9645            ELEC                      United Parcel Service
# 14384           ELEC                                   Spectrum
# 14463           ELEC                 Central Parking - Tower 31
# 14669           ELEC                               Tribeca Park
# ...              ...                                        ...
# 69770           ELEC                             DOCK STATION 9
# 69771           ELEC                            DOCK STATION 10
# 69823           ELEC                      Lincoln Square Garage
# 69940           ELEC                              320 Mason Ave
# 70215           ELEC  Delancey & Essex Municipal Parking Garage
#
#           Street Address                            Intersection Directions  \
# 7777         625 8th Ave                                                NaN
# ...

# %%
can_nulos()
# Out:
#                                   Nulos  Porcentaje
# Federal Agency ID                   375   98.944591
# Federal Agency Code                 375   98.944591
# Federal Agency Name                 375   98.944591
# EV DC Fast Count                    370   97.625330
# Access Detail Code                  364   96.042216
# Intersection Directions             347   91.556728
# Cards Accepted                      347   91.556728
# Facility Type                       119   31.398417
# Owner Type Code                     100   26.385224
# EV Pricing                           88   23.218997
# Restricted Access                    51   13.456464
# Station Phone                        12    3.166227
# EV Level2 EVSE Num                    9    2.374670
# EV Network Web                        9    2.374670
# Access Days Time                      5    1.319261
# Date Last Confirmed                   1    0.263852
# Groups With Access Code (French)      0    0.000000
# ...

# %% [markdown]
# Eliminando 3 columnas por nombre que no es indispensable para los datos

# %%
df.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Station Phone',
#        'Status Code', 'Groups With Access Code', 'Access Days Time',
#        'Cards Accepted', 'EV Level2 EVSE Num', 'EV DC Fast Count',
#        'EV Network', 'EV Network Web', 'Geocode Status', 'Latitude',
#        'Longitude', 'Date Last Confirmed', 'ID', 'Updated At',
#        'Owner Type Code', 'Federal Agency ID', 'Federal Agency Name',
#        'Open Date', 'EV Connector Types', 'Country',
#        'Groups With Access Code (French)', 'Access Code', 'Access Detail Code',
#        'Federal Agency Code', 'Facility Type', 'EV Pricing',
#        'Restricted Access'],
#       dtype='object')

# %%
df = df.drop(['Federal Agency Code', 'Federal Agency ID', 'Federal Agency Name', 'Date Last Confirmed'], axis=1)

# %%
df
# Out:
#       Fuel Type Code                               Station Name  \
# 7777            ELEC                Port Authority Bus Terminal
# 9645            ELEC                      United Parcel Service
# 14384           ELEC                                   Spectrum
# 14463           ELEC                 Central Parking - Tower 31
# 14669           ELEC                               Tribeca Park
# ...              ...                                        ...
# 69770           ELEC                             DOCK STATION 9
# 69771           ELEC                            DOCK STATION 10
# 69823           ELEC                      Lincoln Square Garage
# 69940           ELEC                              320 Mason Ave
# 70215           ELEC  Delancey & Essex Municipal Parking Garage
#
#           Street Address                            Intersection Directions  \
# 7777         625 8th Ave                                                NaN
# ...

# %%
can_nulos()
# Out:
#                                   Nulos  Porcentaje
# EV DC Fast Count                    370   97.625330
# Access Detail Code                  364   96.042216
# Cards Accepted                      347   91.556728
# Intersection Directions             347   91.556728
# Facility Type                       119   31.398417
# Owner Type Code                     100   26.385224
# EV Pricing                           88   23.218997
# Restricted Access                    51   13.456464
# Station Phone                        12    3.166227
# EV Level2 EVSE Num                    9    2.374670
# EV Network Web                        9    2.374670
# Access Days Time                      5    1.319261
# Groups With Access Code               0    0.000000
# Street Address                        0    0.000000
# City                                  0    0.000000
# State                                 0    0.000000
# Access Code                           0    0.000000
# ...

# %%
df.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Station Phone',
#        'Status Code', 'Groups With Access Code', 'Access Days Time',
#        'Cards Accepted', 'EV Level2 EVSE Num', 'EV DC Fast Count',
#        'EV Network', 'EV Network Web', 'Geocode Status', 'Latitude',
#        'Longitude', 'ID', 'Updated At', 'Owner Type Code', 'Open Date',
#        'EV Connector Types', 'Country', 'Groups With Access Code (French)',
#        'Access Code', 'Access Detail Code', 'Facility Type', 'EV Pricing',
#        'Restricted Access'],
#       dtype='object')

# %%
df = df.drop(['Access Detail Code', 'Cards Accepted', 'Intersection Directions', 'Owner Type Code', 'Groups With Access Code (French)', 'Access Days Time', 'ZIP', 'Station Phone'], axis=1)

# %%
df
# Out:
#       Fuel Type Code                               Station Name  \
# 7777            ELEC                Port Authority Bus Terminal
# 9645            ELEC                      United Parcel Service
# 14384           ELEC                                   Spectrum
# 14463           ELEC                 Central Parking - Tower 31
# 14669           ELEC                               Tribeca Park
# ...              ...                                        ...
# 69770           ELEC                             DOCK STATION 9
# 69771           ELEC                            DOCK STATION 10
# 69823           ELEC                      Lincoln Square Garage
# 69940           ELEC                              320 Mason Ave
# 70215           ELEC  Delancey & Essex Municipal Parking Garage
#
#           Street Address      City State Status Code  \
# 7777         625 8th Ave  New York    NY           E
# 9645       643 W 43rd St  New York    NY           E
# ...

# %%
can_nulos()
# Out:
#                          Nulos  Porcentaje
# EV DC Fast Count           370   97.625330
# Facility Type              119   31.398417
# EV Pricing                  88   23.218997
# Restricted Access           51   13.456464
# EV Level2 EVSE Num           9    2.374670
# EV Network Web               9    2.374670
# Longitude                    0    0.000000
# Access Code                  0    0.000000
# Country                      0    0.000000
# EV Connector Types           0    0.000000
# Open Date                    0    0.000000
# Updated At                   0    0.000000
# ID                           0    0.000000
# Fuel Type Code               0    0.000000
# Latitude                     0    0.000000
# Station Name                 0    0.000000
# EV Network                   0    0.000000
# Groups With Access Code      0    0.000000
# Status Code                  0    0.000000
# State                        0    0.000000
# City                         0    0.000000
# ...

# %%
df['EV DC Fast Count'].unique()
# Out:
# array([nan,  2.,  4.,  1.])

# %%
df['EV DC Fast Count'] = df['EV DC Fast Count'].fillna(0)

# %%
df
# Out:
#       Fuel Type Code                               Station Name  \
# 7777            ELEC                Port Authority Bus Terminal
# 9645            ELEC                      United Parcel Service
# 14384           ELEC                                   Spectrum
# 14463           ELEC                 Central Parking - Tower 31
# 14669           ELEC                               Tribeca Park
# ...              ...                                        ...
# 69770           ELEC                             DOCK STATION 9
# 69771           ELEC                            DOCK STATION 10
# 69823           ELEC                      Lincoln Square Garage
# 69940           ELEC                              320 Mason Ave
# 70215           ELEC  Delancey & Essex Municipal Parking Garage
#
#           Street Address      City State Status Code  \
# 7777         625 8th Ave  New York    NY           E
# 9645       643 W 43rd St  New York    NY           E
# ...

# %% [markdown]
# Remplazar los valores si contiene la palabra public

# %%
can_nulos()
# Out:
#                          Nulos  Porcentaje
# Facility Type              119   31.398417
# EV Pricing                  88   23.218997
# Restricted Access           51   13.456464
# EV Level2 EVSE Num           9    2.374670
# EV Network Web               9    2.374670
# Longitude                    0    0.000000
# Access Code                  0    0.000000
# Country                      0    0.000000
# EV Connector Types           0    0.000000
# Open Date                    0    0.000000
# Updated At                   0    0.000000
# ID                           0    0.000000
# Fuel Type Code               0    0.000000
# Latitude                     0    0.000000
# Station Name                 0    0.000000
# EV Network                   0    0.000000
# EV DC Fast Count             0    0.000000
# Groups With Access Code      0    0.000000
# Status Code                  0    0.000000
# State                        0    0.000000
# City                         0    0.000000
# ...

# %%
df['Facility Type'].unique()
# Out:
# array(['PARKING_GARAGE', 'FLEET_GARAGE', 'OFFICE_BLDG', nan, 'FED_GOV',
#        'PAY_GARAGE', 'HOTEL', 'PARKING_LOT', 'COLLEGE_CAMPUS', 'HOSPITAL'],
#       dtype=object)

# %% [markdown]
# Cambiando nan por 'Sin Dato'

# %%
df['Facility Type'] = df['Facility Type'].fillna('Sin Dato')

# %%
can_nulos()
# Out:
#                          Nulos  Porcentaje
# EV Pricing                  88   23.218997
# Restricted Access           51   13.456464
# EV Level2 EVSE Num           9    2.374670
# EV Network Web               9    2.374670
# Longitude                    0    0.000000
# Facility Type                0    0.000000
# Access Code                  0    0.000000
# Country                      0    0.000000
# EV Connector Types           0    0.000000
# Open Date                    0    0.000000
# Updated At                   0    0.000000
# ID                           0    0.000000
# Fuel Type Code               0    0.000000
# Latitude                     0    0.000000
# Station Name                 0    0.000000
# EV Network                   0    0.000000
# EV DC Fast Count             0    0.000000
# Groups With Access Code      0    0.000000
# Status Code                  0    0.000000
# State                        0    0.000000
# City                         0    0.000000
# ...

# %%
df['EV Pricing'] = df['EV Pricing'].fillna('Sin Dato')

# %%
can_nulos()
# Out:
#                          Nulos  Porcentaje
# Restricted Access           51   13.456464
# EV Level2 EVSE Num           9    2.374670
# EV Network Web               9    2.374670
# Longitude                    0    0.000000
# EV Pricing                   0    0.000000
# Facility Type                0    0.000000
# Access Code                  0    0.000000
# Country                      0    0.000000
# EV Connector Types           0    0.000000
# Open Date                    0    0.000000
# Updated At                   0    0.000000
# ID                           0    0.000000
# Fuel Type Code               0    0.000000
# Latitude                     0    0.000000
# Station Name                 0    0.000000
# EV Network                   0    0.000000
# EV DC Fast Count             0    0.000000
# Groups With Access Code      0    0.000000
# Status Code                  0    0.000000
# State                        0    0.000000
# City                         0    0.000000
# ...

# %%
df['Restricted Access'] = df['Restricted Access'].fillna(True)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_17636\566196007.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Restricted Access'] = df['Restricted Access'].fillna(True)

# %%
can_nulos()
# Out:
#                          Nulos  Porcentaje
# EV Level2 EVSE Num           9     2.37467
# EV Network Web               9     2.37467
# Fuel Type Code               0     0.00000
# Longitude                    0     0.00000
# EV Pricing                   0     0.00000
# Facility Type                0     0.00000
# Access Code                  0     0.00000
# Country                      0     0.00000
# EV Connector Types           0     0.00000
# Open Date                    0     0.00000
# Updated At                   0     0.00000
# ID                           0     0.00000
# Geocode Status               0     0.00000
# Latitude                     0     0.00000
# Station Name                 0     0.00000
# EV Network                   0     0.00000
# EV DC Fast Count             0     0.00000
# Groups With Access Code      0     0.00000
# Status Code                  0     0.00000
# State                        0     0.00000
# City                         0     0.00000
# ...

# %%
df['EV Level2 EVSE Num'] = df['EV Level2 EVSE Num'].fillna('Sin Dato')

# %%
df['EV Network Web'] = df['EV Network Web'].fillna('Sin Dato')

# %%
df
# Out:
#       Fuel Type Code                               Station Name  \
# 7777            ELEC                Port Authority Bus Terminal
# 9645            ELEC                      United Parcel Service
# 14384           ELEC                                   Spectrum
# 14463           ELEC                 Central Parking - Tower 31
# 14669           ELEC                               Tribeca Park
# ...              ...                                        ...
# 69770           ELEC                             DOCK STATION 9
# 69771           ELEC                            DOCK STATION 10
# 69823           ELEC                      Lincoln Square Garage
# 69940           ELEC                              320 Mason Ave
# 70215           ELEC  Delancey & Essex Municipal Parking Garage
#
#           Street Address      City State Status Code  \
# 7777         625 8th Ave  New York    NY           E
# 9645       643 W 43rd St  New York    NY           E
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 379 entries, 7777 to 70215
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Fuel Type Code           379 non-null    object
#  1   Station Name             379 non-null    object
#  2   Street Address           379 non-null    object
#  3   City                     379 non-null    object
#  4   State                    379 non-null    object
#  5   Status Code              379 non-null    object
#  6   Groups With Access Code  379 non-null    object
#  7   EV Level2 EVSE Num       379 non-null    object
#  8   EV DC Fast Count         379 non-null    float64
#  9   EV Network               379 non-null    object
#  10  EV Network Web           379 non-null    object
#  11  Geocode Status           379 non-null    object
#  12  Latitude                 379 non-null    float64
#  13  Longitude                379 non-null    float64
# ...

# %%
df_fuel_charging = df

# %% [markdown]
# Para este archivo se realiza la carga de una tabla de  379 filas y 23 columnas, si ejecutas el código ya se ecunentran los datos filtrados y limpios, ademas de losque sóloserán de utilidad para el proyecto.

# %% [markdown]
# La tabla se ecnuetra guardada en un DataFrame llamado df_df_fuel_charging

# %% [markdown]
# Se guardan y exportan los datos limpios en un archivo csv dentro de la carpeta Clean Data en la carpeta Datasets

# %%
df_fuel_charging.to_csv('../Datasets/Clean Data/fuel_charging.csv', index=False)
