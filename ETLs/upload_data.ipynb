# %%
import pandas as pd
import pymysql

# %%
df = pd.read_csv("../Datasets/complete_with_cars.csv")

# %%
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# %%
df
# Out:
#       tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0      2024-06-01 00:34:43   2024-06-01 00:44:45              3.0
# 1      2024-06-01 00:17:58   2024-06-01 00:46:05              2.0
# 2      2024-06-01 00:58:15   2024-06-01 01:39:37              2.0
# 3      2024-06-01 00:05:17   2024-06-01 00:57:22              2.0
# 4      2024-06-01 00:10:00   2024-06-01 00:35:56              2.0
# ...                    ...                   ...              ...
# 75470  2024-06-30 23:19:00   2024-06-30 23:54:15              2.0
# 75471  2024-06-30 23:19:00   2024-06-30 23:54:15              2.0
# 75472  2024-06-30 23:13:09   2024-06-30 23:45:50              3.0
# 75473  2024-06-30 23:07:05   2024-06-30 23:47:18              5.0
# 75474  2024-06-30 23:44:26   2024-07-01 00:43:01              2.0
#
#        trip_distance  RatecodeID PULocationID  DOLocationID  payment_type  \
# 0               4.89         1.0   la guardia           192             2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75475 entries, 0 to 75474
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   tpep_pickup_datetime   75475 non-null  datetime64[ns]
#  1   tpep_dropoff_datetime  75475 non-null  datetime64[ns]
#  2   passenger_count        75475 non-null  float64
#  3   trip_distance          75475 non-null  float64
#  4   RatecodeID             75475 non-null  float64
#  5   PULocationID           75475 non-null  object
#  6   DOLocationID           75475 non-null  int64
#  7   payment_type           75475 non-null  int64
#  8   fare_amount            75475 non-null  float64
#  9   total_amount           75475 non-null  float64
#  10  LocationID             75475 non-null  int64
#  11  Borough                73235 non-null  object
#  12  Zone                   75330 non-null  object
#  13  service_zone           73090 non-null  object
# ...

# %%
# Datos para conectar a la DB
connection = pymysql.connect(
    host='bn83gilwrcfotqoazybx-mysql.services.clever-cloud.com',
    user='uc0tzjpbwmcv8ro5',
    password='LaNI5u2ZjXzafghQRntP',
    db='bn83gilwrcfotqoazybx'
)

# Dropea una tabla si esta existe [[[Dropea la tabla si existe]]]
# Crear un cursor
cursor = connection.cursor()
create_table_query = '''
DROP TABLE IF EXISTS `bn83gilwrcfotqoazybx`.`data_with_cars`
'''
 # Ejecutar la consulta
cursor.execute(create_table_query)
# Confirmar los cambios
connection.commit()


# Crear un cursor   [[Crea la tabla]]]
cursor = connection.cursor()
# Crear una tabla en la DB
create_table_query = '''
CREATE TABLE `bn83gilwrcfotqoazybx`.`data_with_cars` (
`tpep_pickup_datetime` DATETIME, 
`tpep_dropoff_datetime` DATETIME, 
`passenger_count` INT NOT NULL,
`trip_distance` DECIMAL(10,2), 
`RatecodeID` INT NOT NULL, 
`PULocationID` INT NOT NULL, 
`DOLocationID` INT NOT NULL,
`payment_type` INT NOT NULL, 
`fare_amount` DECIMAL(10,2), 
`total_amount` DECIMAL(10,2), 
`LocationID` INT NOT NULL, 
`Borough` VARCHAR(30),
`Zone` VARCHAR(30), 
`service_zone` VARCHAR(30), 
`placa` VARCHAR(30), 
`Brand` VARCHAR(30), 
`Model` VARCHAR(30), 
`AccelSec` DECIMAL(10,2),
`TopSpeed_KmH` INT NOT NULL, 
`Range_Km` INT NOT NULL, 
`Efficiency_WhKm` INT NOT NULL, 
`FastCharge_KmH` VARCHAR(30),
`RapidCharge` VARCHAR(30), 
`PowerTrain` VARCHAR(30), 
`PlugType` VARCHAR(30), 
`BodyStyle` VARCHAR(30), 
`Segment` VARCHAR(30),
`Seats` INT, 
`PriceEuro` INT) ENGINE = InnoDB;;
'''
 # Ejecutar la consulta
cursor.execute(create_table_query)
# Confirmar los cambios
connection.commit()



# Mandar los datos a la DB [[Cargar DATA]]
cursor = connection.cursor()
for i, row in df.iterrows():
    sql = '''
    INSERT INTO `bn83gilwrcfotqoazybx`.`data_with_cars` (
    `tpep_pickup_datetime`,
    `tpep_dropoff_datetime`,
    `passenger_count`,
    `trip_distance`,
    `RatecodeID`,
    `PULocationID',
    `DOLocationID`,
    `payment_type`,
    `fare_amount`,
    `total_amount`,
    `LocationID`,
    `Borough`,
    `Zone`,
    `service_zone`,
    `placa`,
    `Brand`,
    `Model`,
    `AccelSec`,
    `TopSpeed_KmH`,
    `Range_Km`,
    `Efficiency_WhKm`,
    `FastCharge_KmH`,
    `RapidCharge`,
    `PowerTrain`,
    `PlugType`,
    `BodyStyle`,
    `Segment`,
    `Seats`,
    `PriceEuro`) VALUES 
    (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    '''
    cursor.execute(sql, (row['tpep_pickup_datetime'], 
                         row['tpep_dropoff_datetime'], row['passenger_count'], row['trip_distance'], 
                         row['RatecodeID'], row['PULocationID'], row['DOLocationID'], row['payment_type'], row['fare_amount'], 
                         row['total_amount'], row['LocationID'], row['Borough'], row['Zone'], row['service_zone'], row['placa'],
                         row['Brand'], row['Model'], row['AccelSec'], row['TopSpeed_KmH'], row['Range_Km'], 
                         row['Efficiency_WhKm'], row['FastCharge_KmH'], row['RapidCharge'], row['PowerTrain'], row['PlugType'], 
                         row['BodyStyle'], row['Segment'], row['Seats'], row['PriceEuro']))

connection.commit()

# Cerrar la conexión
connection.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[5], line 99
#      65 for i, row in df.iterrows():
#      66     sql = '''
#      67     INSERT INTO `bn83gilwrcfotqoazybx`.`data_with_cars` (
#      68     `tpep_pickup_datetime`,
#    (...)
#      97     (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#      98     '''
# ---> 99     cursor.execute(sql, (row['tpep_pickup_datetime'],
#     100                          row['tpep_dropoff_datetime'], row['passenger_count'], row['trip_distance'],
#     101                          row['RatecodeID'], row['PULocationID'], row['DOLocationID'], row['payment_type'], row['fare_amount'],
#     102                          row['total_amount'], row['LocationID'], row['Borough'], row['Zone'], row['service_zone'], row['placa'],
# ...

# %%
# Cerrar la conexión
connection.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Cerrar la conexión
# ----> 2 connection.close()
#
# NameError: name 'connection' is not defined

# %%
from sqlalchemy import create_engine

# %%
# Variables para la DB
host = 'byzuegyhogks28kbhbkn-mysql.services.clever-cloud.com'
user = 'uqpk8ogwqurgzkhh'
password = 'uXvAxUEyxLSo9dnvub27'
db = 'byzuegyhogks28kbhbkn'

#  Motor de la DB
engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}/{db}')


# Envía el DataFrame a la base de datos
df.to_sql('data_with_cars', engine, if_exists='replace', index=False)
# Out:
# 75475

# %% [markdown]
# ---
# ---
# ---

# %%
df = pd.read_csv("../Datasets/complete_with_placas.csv")

# %%
df.columns
# Out:
# Index(['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count',
#        'trip_distance', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'total_amount', 'LocationID', 'Borough',
#        'Zone', 'service_zone', 'placa'],
#       dtype='object')

# %%
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# %%
# Variables para la DB
host = 'byzuegyhogks28kbhbkn-mysql.services.clever-cloud.com'
user = 'uqpk8ogwqurgzkhh'
password = 'uXvAxUEyxLSo9dnvub27'
db = 'byzuegyhogks28kbhbkn'

#  Motor de la DB
engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}/{db}')


# Envía el DataFrame a la base de datos
df.to_sql('data_with_placas', engine, if_exists='replace', index=False)
# Out:
# 75475
