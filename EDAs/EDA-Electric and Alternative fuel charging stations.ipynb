# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# B.	Electric and alternative fuel charging stations.csv
# ---
#
# Estaciones de carga de combustibles eléctricos y alternativos con 70406 filas de datos
# -
# El dataset contiene información sobre las centrales donde se puede cargar combustible alternativo para vehículos

# %%
df = pd.read_csv('../Datasets/Electric and Alternative Fuel Charging Stations.csv')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14624\3514369627.py:1: DtypeWarning: Columns (6,16,20,31,33,36,39,40,41,43,46,52,53,55,57,58,60,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Datasets/Electric and Alternative Fuel Charging Stations.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70406 entries, 0 to 70405
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fuel Type Code                    70406 non-null  object
#  1   Station Name                      70406 non-null  object
#  2   Street Address                    70405 non-null  object
#  3   Intersection Directions           4492 non-null   object
#  4   City                              70406 non-null  object
#  5   State                             70406 non-null  object
#  6   ZIP                               70405 non-null  object
#  7   Plus4                             0 non-null      float64
#  8   Station Phone                     65204 non-null  object
#  9   Status Code                       70406 non-null  object
#  10  Expected Date                     1218 non-null   object
# ...

# %%
df.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0            CNG          Spire - Montgomery Operations Center
# 1            CNG                           PS Energy - Atlanta
# 2            CNG  Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                         United Parcel Service
# 4            CNG                    Arkansas Oklahoma Gas Corp
#
#          Street Address                            Intersection Directions  \
# 0      2951 Chestnut St                                                NaN
# 1      340 Whitehall St  From I-7585 N, exit 91 to Central Ave, left on...
# 2   2424 Piedmont Rd NE                                                NaN
# 3  270 Marvin Miller Dr                                                NaN
# 4     2100 S Waldron Rd                                                NaN
#
#          City State    ZIP  Plus4 Station Phone Status Code  ...  \
# 0  Montgomery    AL  36107    NaN           NaN           E  ...
# ...

# %%
# Ajustar opciones de visualización
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Obtener el conteo de nulos por columna de df
null_count = df.isnull().sum()

# Obtener el porcentaje de nulos por columna
null_percentage = (df.isnull().mean()) * 100

# Crear un nuevo DataFrame con la información de conteo y porcentaje
null_info = pd.DataFrame({
    'Nulos': null_count,
    'Porcentaje': null_percentage
})

# Imprimir el nuevo DataFrame
print(null_info.sort_values('Nulos', ascending=False))
# Out:
#                                   Nulos  Porcentaje
# Plus4                             70406  100.000000
# BD Blends (French)                70404   99.997159
# EV Other Info                     70357   99.930404
# LNG On-Site Renewable Source      70344   99.911939
# Hydrogen Status Link              70323   99.882112
# Hydrogen Standards                70290   99.835241
# Hydrogen Pressures                70290   99.835241
# Hydrogen Is Retail                70289   99.833821
# LNG Vehicle Class                 70248   99.775587
# Intersection Directions (French)  70218   99.732977
# EV Level1 EVSE Num                70120   99.593785
# CNG Storage Capacity              70049   99.492941
# EV On-Site Renewable Source       70036   99.474477
# CNG Total Compression Capacity    69698   98.994404
# CNG On-Site Renewable Source      69690   98.983041
# Federal Agency Name               69451   98.643582
# Federal Agency ID                 69451   98.643582
# ...

# %%
# Configurar la figura con X columnas y Y filas
fig, axes = plt.subplots(4, 5, figsize=(20, 24))


# Aplanar los ejes para iterar fácilmente
axes = axes.flatten()

# Crear un boxplot para cada variable
for i, col in enumerate(df.columns[:20]):  # Asegúrate de tener 20 columnas
    sns.boxplot(data=df, x=col, ax=axes[i])
    # axes[i].set_title(col)

# Ajustar el layout para evitar solapamiento
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "T1R 1P7"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 10
#       8 # Crear un boxplot para cada variable
#       9 for i, col in enumerate(df.columns[:20]):  # Asegúrate de tener 20 columnas
# ---> 10     sns.boxplot(data=df, x=col, ax=axes[i])
#      11     # axes[i].set_title(col)
#      12
#      13 # Ajustar el layout para evitar solapamiento
#      14 plt.tight_layout()
#
# ...

# %% [markdown]
# Se observa que existen una cantidad de columnas con demasiados nulos, sin embargo en el dataset hay datos de estaciones de carga de coches electricos y de combustible alternativo, loq ue quiere decir que algunas estaciones de carga no ofrecen todos los servicios de carga de combustible, es decir unas de ellas sólo ofrecen un tipo de combustible al publico, está es la razón mas lógica del por que existen demasiados datos nulos.

# %%
df.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Plus4',
#        'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'BD Blends', 'NG Fill Type Code', 'NG PSI', 'EV Level1 EVSE Num',
#        'EV Level2 EVSE Num', 'EV DC Fast Count', 'EV Other Info', 'EV Network',
#        'EV Network Web', 'Geocode Status', 'Latitude', 'Longitude',
#        'Date Last Confirmed', 'ID', 'Updated At', 'Owner Type Code',
#        'Federal Agency ID', 'Federal Agency Name', 'Open Date',
#        'Hydrogen Status Link', 'NG Vehicle Class', 'LPG Primary',
#        'E85 Blender Pump', 'EV Connector Types', 'Country',
#        'Intersection Directions (French)', 'Access Days Time (French)',
#        'BD Blends (French)', 'Groups With Access Code (French)',
#        'Hydrogen Is Retail', 'Access Code', 'Access Detail Code',
# ...

# %%
#resetear los valores por defecto de sns
sns.reset_defaults()

# %%
# Generamos un mapa de calor con las correlaciones de los todos los datos que contengan números 
dataNumerica = df.select_dtypes(include=['number']) 
corr = dataNumerica.corr().round(2)

plt.figure(figsize=(20,15))
sns.heatmap(corr, cmap="coolwarm", annot=True)
plt.title('Mapa de Correlación - Variables numéricas')
plt.show()

# %% [markdown]
# La mayoría de las columnas son de tipo objeto por lo que los graficos bloxplot y el mapa de correlacion no muestran suficiente información

# %% [markdown]
# ---
# Fuel Type Code
# ---
# ---

# %%
colum = 'Fuel Type Code'
plt.figure(figsize=(20, 10))
sns.countplot(x=colum, data=df, palette='bright')
plt.title(colum)
plt.xlabel(colum)
plt.ylabel('conteo')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\3829009145.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=colum, data=df, palette='bright')

# %%
df[colum].value_counts().sort_values(ascending=False)
# Out:
# Fuel Type Code
# ELEC    60907
# E85      4508
# LPG      1867
# CNG      1631
# BD       1218
# LNG       158
# HY        117
# Name: count, dtype: int64

# %% [markdown]
# Los codigos de combustible significan:
#
#     Elec = eléctrico
#     E85 = etanol al 85% y 15 gaolina
#     LPG = Gas Licuado de Petroleo
#     CNG = Gas Natural Comprimido
#     BD = Gas de Biodigestores
#     LNG = Gas Natural Licuado
#     HY = Hidrogeno
#
# En ese orden existe el producto en disposicipon en las estaciones de servicio

# %% [markdown]
# ---
# Station Name
# ---
# ---

# %%
len(df['Station Name'].unique())
# Out:
# 62835

# %% [markdown]
# Existen 62835 Diferenetes nombres de estaciones de servicio, el nombre no es indispensable, sin embargo es bueno conservarlo para futuras consultas

# %% [markdown]
# ---
# Street Address
# ---
# ---

# %%
len(df['Street Address'].unique())
# Out:
# 52296

# %% [markdown]
# De igual forma existen 52296 nombres de calles diferentes en el dataset, mismo caso que el anterior, no son indispensables, pero puede conservarse

# %% [markdown]
# ---
# Intersection Directions (direcciones con intersección)
# ---
# ---

# %%
len(df['Street Address'].unique())
# Out:
# 52296

# %% [markdown]
# De igual forma existen 52296 nombres de calles diferentes en el dataset, mismo caso que el anterior, no son indispensables, pero puede conservarse

# %% [markdown]
# ---
# City
# ---
# ---

# %%
len(df['City'].unique())
# Out:
# 8278

# %% [markdown]
# Existen gran cantidad de ciudades 8278 con estaciones de carga, por lo que se realizará un top 25, para saber cuales son aquellas en donde existen más estaciones de servcicio.

# %%
col = 'City'
top_30 = df[col].value_counts().nlargest(30)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
plt.xlabel(col)
plt.ylabel('Frecuencia')
plt.title(f'Top 20 de {col}')
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\1131644467.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
top_30
# Out:
# City
# Los Angeles      1586
# San Diego         918
# Montréal          635
# Atlanta           608
# San Jose          587
# Irvine            580
# Austin            579
# Kansas City       463
# San Francisco     453
# Seattle           429
# Boston            396
# New York          381
# Menlo Park        364
# Washington        359
# Houston           354
# Santa Clara       340
# Richmond          332
# Sacramento        325
# Phoenix           321
# Denver            312
# Columbus          310
# Chicago           309
# Toronto           299
# Baltimore         297
# Vancouver         278
# Miami             259
# Las Vegas         259
# Fresno            249
# Portland          245
# Long Beach        240
# Name: count, dtype: int64

# %% [markdown]
# Las ciudades donde existe mayor cantidad de estaciones de carga de combustible alternativo son Los Angeles, San Diego, Montreal entre otras.

# %% [markdown]
# ---
# State
# ---
# ---

# %%
len(df['State'].unique())
# Out:
# 65

# %% [markdown]
# Existen 65 diferentes estados en el dataset

# %%
col = 'State'
top_30 = df[col].value_counts().nlargest(30)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
plt.xlabel(col)
plt.ylabel('Frecuencia')
plt.title(f'Top 20 de Cantidad de estaciones por {col}')
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\2358996043.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
top_30
# Out:
# State
# CA    16106
# QC     3502
# NY     3409
# FL     3113
# TX     3002
# ON     2472
# MA     2385
# WA     1916
# CO     1894
# GA     1763
# IL     1636
# PA     1591
# BC     1565
# MD     1473
# NC     1461
# OH     1417
# MI     1414
# VA     1351
# MN     1293
# MO     1227
# AZ     1104
# OR     1068
# IA      949
# UT      925
# NJ      884
# TN      847
# WI      796
# IN      693
# KS      606
# OK      591
# Name: count, dtype: int64

# %% [markdown]
# Se puede notar como en California existen mayor numero de estaciones de carga de combustible alternativo
#
# Nueva York esta en el peldaño numero 3 con 3409 estaciones de servicio

# %% [markdown]
# ---
# ZIP
# ---
# ---

# %%
col = 'ZIP'
len(df[col].unique())
# Out:
# 22183

# %%
top_30 = df[col].value_counts().nlargest(30)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
plt.xlabel(col)
plt.ylabel('Frecuencia')
plt.title(f'Top 20 de Cantidad de estaciones por {col} (Codigo postal)')
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\1704382818.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %% [markdown]
# ---
# Plus4
# ---
# ---

# %%
col = 'Plus4'
len(df[col].unique())
# Out:
# 1

# %%
df[col].unique()
# Out:
# array([nan])

# %% [markdown]
# No existen datos en esta columna, todos son nulos

# %% [markdown]
# ---
# Station Phone
# ---
# ---

# %%
col = 'Station Phone'
len(df[col].unique())
# Out:
# 17060

# %% [markdown]
# Como tal esta columna no arroja información esencial o crucial para el proyecto, pero se puede conservar para dar la información al cliente

# %% [markdown]
# ---
# Status Code
# ---
# ---

# %%
colum = 'Status Code'
len(df[colum].unique())
# Out:
# 3

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=colum, data=df, palette='bright')
plt.title(colum)
plt.xlabel(colum)
plt.ylabel('Frecuencia')
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\130187848.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=colum, data=df, palette='bright')

# %%
df[colum].value_counts()
# Out:
# Status Code
# E    69188
# P      986
# T      232
# Name: count, dtype: int64

# %% [markdown]
# El el dataset no se especifica que signifiquen los valores mostradossin embargo lo siguiente puede ser una suposicion:
#
# (Enabled, Training, Pending)

# %% [markdown]
# ---
# Expected Date - Fecha de Emisión
# ---
# ---

# %%
colum = 'Expected Date'
len(df[colum].unique())
# Out:
# 146

# %%
df[colum].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df[colum].min()
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6487, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6479 @doc(make_doc("min", ndim=1))
#    6480 def min(
#    6481     self,
#    (...)
#    6485     **kwargs,
#    6486 ):
# -> 6487     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12381, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12374 def min(
#   12375     self,
#   12376     axis: Axis | None = 0,
#    (...)
#   12379     **kwargs,
#   12380 ):
# > 12381     return self._stat_function(
#   12382         "min",
#   12383         nanops.nanmin,
#   12384         axis,
# ...

# %%
df[colum].max()
# Out:
# Timestamp('2023-06-30 00:00:00')

# %% [markdown]
# La fecha menor registrada en el dataset es del año 1987
#
# La fecha mayor registrada es del año 2023

# %%
top_30 = df[colum].value_counts().nlargest(30)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
plt.xlabel(colum)
plt.ylabel('Frecuencia')
plt.title(f'{colum}(Fecha de emision)')
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\3419601213.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
df_dates = df[colum].value_counts()

# %%
df_dates['año'] = df[colum].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df_dates['año'] = df[colum].dt.year
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6293, in NDFrame.__getattr__(self, name)
#    6286 if (
#    6287     name not in self._internal_names_set
#    6288     and name not in self._metadata
#    6289     and name not in self._accessors
#    6290     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291 ):
#    6292     return self[name]
# -> 6293 return object.__getattribute__(self, name)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=df[colum].dt.year, palette='bright')
plt.xlabel(colum)
plt.ylabel('Frecuencia')
plt.title(f'Apertura de estaciones de combustible por año')
plt.xticks(rotation=90) 
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\959429648.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum].dt.year, palette='bright')

# %%
df_dates['año'].value_counts()
# Out:
# Expected Date
# 2022.0    1098
# 2021.0      65
# 2020.0      27
# 2023.0      13
# 2019.0       4
# 2017.0       3
# 2013.0       2
# 2009.0       1
# 2014.0       1
# 2015.0       1
# 1987.0       1
# 2018.0       1
# 2016.0       1
# Name: count, dtype: int64

# %% [markdown]
# Se puede notar como en el año 2022 crecieron significativamente las estaciones de servicio de combustible alternativo

# %% [markdown]
# ---
# Groups With Access Code - Grupos con códigos de acceso
# ---
# ---

# %%
colum = 'Groups With Access Code'
df[colum].unique()
# Out:
# array(['Private', 'Public - Card key at all times',
#        'Private - Government only', 'Public - Credit card at all times',
#        'TEMPORARILY UNAVAILABLE (Public)',
#        'TEMPORARILY UNAVAILABLE (Public - Credit card at all times)',
#        'Private - Fleet customers only', 'Public',
#        'Public - Credit card after hours',
#        'TEMPORARILY UNAVAILABLE (Private)',
#        'Private - Card key at all times', 'Public - Call ahead',
#        'Public - Card key after hours',
#        'TEMPORARILY UNAVAILABLE (Public - Credit card after hours)',
#        'TEMPORARILY UNAVAILABLE (Public - Call ahead)',
#        'TEMPORARILY UNAVAILABLE (Private - Government only)',
#        'PLANNED - not yet accessible (Public - Credit card at all times)',
#        'PLANNED - not yet accessible (Private - Government only)',
#        'Public - Limited hours', 'PLANNED - not yet accessible (Public)',
#        'PLANNED - not yet accessible (Public - Call ahead)',
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=df[colum], palette='bright')
plt.xlabel(colum)
plt.ylabel('Frecuencia')
plt.title(f'Grupos de acceso')
plt.xticks(rotation=90) 
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\3094372963.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
df[colum].value_counts()
# Out:
# Groups With Access Code
# Public                                                              58045
# Private                                                              3849
# Public - Credit card at all times                                    3629
# Public - Call ahead                                                  1776
# Private - Government only                                             939
# PLANNED - not yet accessible (Public)                                 795
# Public - Credit card after hours                                      539
# Public - Card key at all times                                        214
# TEMPORARILY UNAVAILABLE (Public)                                      144
# PLANNED - not yet accessible (Private)                                130
# Private - Fleet customers only                                         79
# PLANNED - not yet accessible (Public - Credit card at all times)       58
# ...

# %% [markdown]
# ---
# Access Days Time - Accesos por día y hora
# ---
# ---

# %%
colum = 'Access Days Time'
df[colum].unique()
# Out:
# array([nan, '24 hours daily',
#        '24 hours daily; call 866-809-4869 for Clean Energy card', ...,
#        '7:30am-7pm M-F; 8am-6pm Sat; Closed Sunday',
#        '24 hours daily; Phone App',
#        'Mon 7:00am - 6:00pm; Tue 7:00am - 6:00pm; Wed 7:00am - 6:00pm; Thu 7:00am - 6:00pm; Fri 7:00am - 6:00pm'],
#       dtype=object)

# %%
top_30 = df[colum].value_counts().nlargest(30)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
plt.xlabel(colum)
plt.ylabel('Frecuencia')
plt.title(f'Top 30 {colum}')
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\3940660168.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\3940660168.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
top_30
# Out:
# Access Days Time
# 24 hours daily                                                                                                                                              45817
# 24 hours daily; for customer use only; see front desk for access                                                                                             2276
# MO: Not Specified; TU: Not Specified; WE: Not Specified; TH: Not Specified; FR: Not Specified; SA: Not Specified; SU: Not Specified                          1698
# MON: 24 hours | TUE: 24 hours | WED: 24 hours | THU: 24 hours | FRI: 24 hours | SAT: 24 hours | SUN: 24 hours                                                1499
# 24 hours daily; for Tesla use only                                                                                                                           1280
# ...

# %% [markdown]
# Exiten 45817 estaciones que abren diario las 24 horas

# %% [markdown]
# ---
# Cards Accepted
# ---
# ---

# %%
colum = 'Cards Accepted'
df[colum].unique()
# Out:
# array([nan, 'Comdata FleetOne FuelMan Voyager Wright_Exp',
#        'FuelMan M V Wright_Exp',
#        'A CleanEnergy Comdata D FuelMan M V Voyager Wright_Exp',
#        'CleanEnergy D FleetOne FuelMan M V Voyager Wright_Exp',
#        'CleanEnergy D FuelMan M V Voyager Wright_Exp',
#        'CleanEnergy D FleetOne FuelMan M Proprietor V Voyager Wright_Exp',
#        'D M V Wright_Exp', 'CleanEnergy',
#        'A Cash Comdata D FuelMan M V Voyager Wright_Exp',
#        'Comdata FuelMan GasCard M V Wright_Exp',
#        'A CleanEnergy D FleetOne FuelMan M Proprietor V Voyager Wright_Exp',
#        'A D M V Voyager Wright_Exp', 'D FuelMan M V Wright_Exp',
#        'CleanEnergy D FuelMan M Proprietor V Voyager Wright_Exp',
#        'A CleanEnergy Comdata D FleetOne FuelMan M V Voyager Wright_Exp',
#        'GasCard M V Wright_Exp',
#        'Comdata D GasCard M Proprietor V Wright_Exp',
#        'Comdata GasCard M V Wright_Exp',
#        'A D M Proprietor V Voyager Wright_Exp',
# ...

# %%
top_30 = df[colum].value_counts().nlargest(30)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
plt.xlabel(colum)
plt.ylabel('Frecuencia')
plt.title(f'Top 30 {colum}')
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\3940660168.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\3940660168.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
top_30
# Out:
# Cards Accepted
# A D Debit M V                                                                                                 2317
# A Cash D Debit M V                                                                                            1268
# A Cash D M V                                                                                                   940
# A Cash D M V Voyager Wright_Exp                                                                                838
# A D M V                                                                                                        572
# A Cash Checks D M V Voyager Wright_Exp                                                                         419
# A Cash D FuelMan M V Voyager Wright_Exp                                                                        264
# A Cash Checks D M V                                                                                            231
# ...

# %%
def graficar_conteo(colum):
    ret = df[colum].unique()
    if (len(df[colum].unique()) > 30):
        top_30 = df[colum].value_counts().nlargest(30)
        plt.figure(figsize=(10, 6))
        sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
        plt.xlabel(colum)
        plt.ylabel('Frecuencia')
        plt.title(f'Top 30 {colum}')
        plt.xticks(rotation=90) 
        plt.tight_layout()
        plt.show()
        return top_30
    else:
        plt.figure(figsize=(10, 6))
        sns.countplot(x=df[colum], palette='bright')
        plt.xlabel(colum)
        plt.ylabel('Frecuencia')
        plt.title(f'{colum}')
        plt.xticks(rotation=90) 
        plt.show()
        return df[colum].value_counts()

# %% [markdown]
# ---
# BD Blends - Mezclas de biodiesel
# ---
# ---

# %%
colum = 'BD Blends'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\1530776073.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
cont
# Out:
# BD Blends
# B20 in summer, B5 in winter             637
# B20                                     490
# B20, B5                                  33
# B99                                      10
# B99, B20                                  5
# B20 in summer                             4
# B100                                      4
# B99, B20, B5                              3
# B20 in summer, B10 in winter              3
# B100, B50, B20                            2
# B20 in summer, B11 in winter              2
# B100 and B20 in summer, B5 in winter      2
# B20 in the summer, B5 in the winter       2
# B80 in summer, B50 in winter              1
# B30, any blend up to B30 available        1
# B20-B99                                   1
# b20                                       1
# B5-B100                                   1
# B5-B99                                    1
# B20 in winter                             1
# B20, B10, B5                              1
# ...

# %% [markdown]
# Los combustibles en mezclas de Biodiesel más comunes en el dataset son: B20 in summer, B5 in Winter con 637 conteos
# B20 con 490 y B20, B5 con 33

# %% [markdown]
# ---
# BD Blends - Código de llenado de gas natural
# ---
# ---

# %%
colum = 'NG Fill Type Code'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# NG Fill Type Code
# Q    1155
# T     248
# B     200
# Name: count, dtype: int64

# %% [markdown]
# (B a granel, Q llenado rápido, T Llenado parcial)

# %% [markdown]
# ---
# 'NG PSI' - Medida de presión de gas natural
# ---
# ---

# %%
colum = 'NG PSI'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# NG PSI
# 3600         1126
# 3000 3600     232
# 3600.0        174
# 3000           61
# 3000.0          4
# Name: count, dtype: int64

# %% [markdown]
# La presión con la que se lleva a cabo el llenado más común es a 3600 PSI

# %% [markdown]
# ---
# 'EV Level1 EVSE Num', Indica el número total de puntos de recarga de nivel 1 disponibles para vehículos eléctricos en una estación de recarga. 120 volts
# ---
# ---

# %%
colum = 'EV Level1 EVSE Num'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# EV Level1 EVSE Num
# 1.0     166
# 2.0      56
# 4.0      16
# 10.0      7
# 6.0       6
# 5.0       6
# 3.0       6
# 18.0      3
# 15.0      3
# 22.0      2
# 8.0       2
# 23.0      1
# 47.0      1
# 16.0      1
# 40.0      1
# 51.0      1
# 12.0      1
# 19.0      1
# 17.0      1
# 28.0      1
# 20.0      1
# 9.0       1
# 42.0      1
# 11.0      1
# Name: count, dtype: int64

# %% [markdown]
# 166 estaciones cuentan comunemente con 1 punto de recarga de corriente continua a 120v

# %% [markdown]
# ---
# 'EV Level2 EVSE Num', indica el número total de puntos de recarga de nivel 2 disponibles para vehículos eléctricos en una estación de recarga. 240 volts
# ---
# ---

# %%
colum = 'EV Level2 EVSE Num'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
cont
# Out:
# EV Level2 EVSE Num
# 2.0     33310
# 1.0     13105
# 4.0      2978
# 3.0      2053
# 6.0       813
# 8.0       387
# 5.0       365
# 10.0      327
# 12.0      133
# 7.0       118
# 9.0        93
# 14.0       60
# 16.0       57
# 20.0       50
# 11.0       37
# 24.0       26
# 15.0       24
# 18.0       23
# 17.0       19
# 13.0       15
# 22.0       13
# 26.0       13
# 19.0        9
# 32.0        8
# 40.0        7
# 25.0        7
# 27.0        6
# 23.0        6
# 28.0        6
# 21.0        5
# Name: count, dtype: int64

# %% [markdown]
# La mayoria de las estaciones de carga cuentan con 2 puntos de recarga de 240 volts, es más común que el de 120 volts. En segundo lugar las estaciones cuentan con solo 1 unto de recarga con 240volts, casi 3k en la totalidad del set tienen 4 puntos de recarga y mas de 2k tienen 3 puntos para recargar vehiculos electricos

# %% [markdown]
# ---
# EV DC Fast Count,  indica el número total de puntos de recarga de corriente continua de alta velocidad disponibles para vehículos eléctricos en una estación de recarga
# ---
# ---

# %%
colum = 'EV DC Fast Count'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
cont
# Out:
# EV DC Fast Count
# 1.0     3755
# 2.0     1501
# 4.0      889
# 8.0      885
# 6.0      307
# 3.0      262
# 12.0     257
# 10.0     148
# 16.0      89
# 20.0      63
# 14.0      35
# 5.0       23
# 24.0      21
# 7.0       18
# 18.0      15
# 9.0        8
# 28.0       4
# 11.0       4
# 22.0       4
# 40.0       3
# 26.0       3
# 56.0       2
# 21.0       2
# 19.0       1
# 35.0       1
# 13.0       1
# 32.0       1
# 30.0       1
# 36.0       1
# 34.0       1
# Name: count, dtype: int64

# %% [markdown]
# La mayor parte de las estaciones de carga tienen 1 punto de carga rápida

# %% [markdown]
# ---
# 'EV Other Info', permite proporcionar detalles adicionales que pueden ser útiles para los usuarios de vehículos eléctricos, pero que no encajan en las categorías anteriores.
# ---
# ---

# %%
colum = 'EV Other Info'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# EV Other Info
# L2                    17
# 1 SP Inductive        16
# DCFC                   8
# 1 LP Inductive         3
# 3 SP Inductive         1
# 2 Tesla Conductive     1
# 1 Tesla Conductive     1
# 1 Conductive 120V      1
# 7 Conductive 120V      1
# Name: count, dtype: int64

# %% [markdown]
# Los tipo de puntos de recarga con mayor presencia en el dataset son liderados por L2 (un tipo de vehiculo de 3 ruedas), 1 SP Inductive se ecnuentra en el segundo lugar. Es decir que en las estaciones de servicio, exiten en su mayoría más de estos servicios.

# %% [markdown]
# ---
# 'EV Network',   indicar a qué red de recarga pertenece una estación de recarga específica, lo que puede ser útil para los usuarios de vehículos eléctricos que buscan estaciones de recarga compatibles con su vehículo o que desean acceder a beneficios o descuentos exclusivos.
# ---
# ---

# %%
colum = 'EV Network'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
cont
# Out:
# EV Network
# ChargePoint Network    29680
# Non-Networked          10602
# Tesla Destination       4906
# SemaCharge Network      2178
# Circuit électrique      1986
# FLO                     1956
# Tesla                   1575
# Blink Network           1511
# Volta                   1240
# Greenlots               1115
# EV Connect               979
# eVgo Network             913
# Electrify America        814
# LIVINGSTON               192
# OpConnect                164
# SWTCH                    157
# POWERFLEX                128
# FCN                      117
# BCHYDRO                   85
# eCharge Network           79
# IVY                       71
# CHARGELAB                 68
# EVCS                      62
# Webasto                   61
# PETROCAN                  57
# AMPUP                     51
# RIVIAN_WAYPOINTS          48
# EVGATEWAY                 40
# Electrify Canada          31
# RIVIAN_ADVENTURE          16
# Name: count, dtype: int64

# %% [markdown]
# En la lista de arriba se muestra el orden en que existen estos servicios en las estaciones de carga

# %% [markdown]
# ---
# Geocode Status,  Estado de la asignación de coordenadas geográficas
# ---
# ---

# %%
colum = 'Geocode Status'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# Geocode Status
# GPS      51574
# 200-9    14506
# 200-8     4241
# 200-6       56
# 200-5       11
# 200-7        2
# 200-4        1
# Name: count, dtype: int64

# %% [markdown]
# Se muestra como se adignaron las coordenadas geográficas, mediante que servicio se implemento.

# %% [markdown]
# ---
# Date Last Confirmed. Ultima fecha de confirmacion
# ---
# ---

# %%
colum = 'Date Last Confirmed'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %% [markdown]
# El año en donde se incremento o actualizó la información sobre los vehículos eléctricos es el 2022.

# %%
df[colum] = pd.to_datetime(df[colum])

# %%
df[colum].dt.year.value_counts()
# Out:
# Date Last Confirmed
# 2022.0    51523
# 2021.0    10483
# 2020.0     8016
# 2019.0      131
# 2018.0       21
# 2017.0       14
# Name: count, dtype: int64

# %% [markdown]
# Se Observa en las fechas confirmadas que 2022 es el año con mayor numero de regitros
# De igual forma el año con menor numero es 2017, por loq ue se deduce que conforme avanza el tiempo también el número de confirmaciones de estaciones de carga de combustible alternativo

# %% [markdown]
# ---
# Updated At
# ---
# ---

# %%
df['Date Last Confirmed']
# Out:
# 0       2022-06-14
# 1       2021-08-04
# 2       2021-08-04
# 3       2022-06-14
# 4       2022-06-14
#            ...
# 70401   2022-07-25
# 70402   2022-07-25
# 70403   2022-07-25
# 70404   2022-07-25
# 70405   2022-07-25
# Name: Date Last Confirmed, Length: 70406, dtype: datetime64[ns]

# %%
colum = 'Updated At'
df[colum]
# Out:
# 0        2022-06-14 16:22:47 UTC
# 1        2022-02-10 19:42:29 UTC
# 2        2022-02-10 19:42:29 UTC
# 3        2022-06-14 16:22:47 UTC
# 4        2022-06-14 16:22:47 UTC
#                   ...
# 70401    2022-07-25 00:58:13 UTC
# 70402    2022-07-25 01:22:29 UTC
# 70403    2022-07-25 01:30:43 UTC
# 70404    2022-07-25 01:48:14 UTC
# 70405    2022-07-25 01:48:14 UTC
# Name: Updated At, Length: 70406, dtype: object

# %% [markdown]
# Comparando las columnas que tienen fechas se deduce que son las mismas fechas sin embargo en una columna también se tienen datos horarios

# %% [markdown]
# ---
# Owner Type Code. Código del tipo de dueño de la estación de servicio (T: transporte, P: Privado, LG: Gobierno local, SG: Gobierno estatal, FG: Gobierno Federal, J, Jurisdicción)
# ---
# ---

# %%
colum = 'Owner Type Code'
df[colum] = df[colum].fillna('Sin dato')

# %%
df[colum].value_counts()
# Out:
# Owner Type Code
# Sin dato    40216
# P           25636
# LG           1961
# FG            958
# T             931
# SG            685
# J              19
# Name: count, dtype: int64

# %%
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %% [markdown]
# dentro del dataset se tienen datos que reporesentan los dueños de las estaciones de servicio, y se nota que la mayor cantidad de datos no es conocida.
#
# en segundo lugar están las estaciones donde el tipo de dueño es Privada y en ultimo lugar esta Jurisdiccion.

# %% [markdown]
# ---
# 31.	'Federal Agency ID'
# ---
# ---

# %%
colum = 'Federal Agency ID'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
colum = 'Federal Agency Name'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# Federal Agency Name
# Department of Navy                               200
# Department of the Interior                       134
# U.S. Department of Energy                        126
# United States Marine Corps                        78
# Department of Air Force                           69
# Department of Army                                58
# Department of Veterans Affairs                    58
# Department of Transportation                      27
# National Aeronautics and Space Administration     24
# Department of Justice                             24
# U.S. Department of Agriculture                    22
# Department of Homeland Security                   20
# U.S. Postal Service                               19
# U.S. Environmental Protection Agency              15
# Defense Agencies                                  14
# Department of Health and Human Services           14
# Smithsonian Institution                           12
# ...

# %% [markdown]
# La agencia federal que tiene mas estaciones de carga a su cargo es Department of Navy, en segundo lugar esta Department of the interior y en tercer lugar US Department of energy

# %% [markdown]
# ---
# 'Open Date'
# ---
# ---

# %%
colum = 'Open Date'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
df[colum] = pd.to_datetime(df[colum])
df[colum].dt.year.value_counts()
# Out:
# Open Date
# 2021.0    22048
# 2020.0    10170
# 2022.0     8792
# 2019.0     7026
# 2018.0     3864
# 2017.0     3048
# 2016.0     2944
# 2015.0     2778
# 2012.0     1984
# 2014.0     1589
# 2011.0     1325
# 2013.0     1148
# 2009.0      329
# 2000.0      316
# 2010.0      305
# 2008.0      304
# 2007.0      262
# 2006.0      216
# 2005.0      157
# 1999.0      146
# 2003.0      111
# 1996.0       88
# 2002.0       69
# 2004.0       65
# 2001.0       49
# 1998.0       38
# 1997.0       38
# 1995.0       25
# 1993.0       12
# 1987.0       12
# 1992.0       11
# 1994.0       10
# 1991.0        9
# 1989.0        5
# 1990.0        4
# 1988.0        4
# 1985.0        2
# 1980.0        2
# 1986.0        1
# 1974.0        1
# 1984.0        1
# 1983.0        1
# 1978.0        1
# Name: count, dtype: int64

# %% [markdown]
# Esta columna es muy importante puesto que se tienen registros de las fechas de apertura con dia, mes y año por lo que se puede llegar a un estudio muy importante y completo.
#
# En la lista anterior se tiene un conteo general de los años en que fueron aperturadas mayormente estaciones de servicio.

# %% [markdown]
# ---
# NG Vehicle Class - Clasificacion de vehiculos a gas Naturas, se cre que están clasificados por su peso
# ---
# ---

# %%
colum = 'NG Vehicle Class'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# NG Vehicle Class
# HD    1489
# MD     254
# LD      37
# Name: count, dtype: int64

# %% [markdown]
# En el dataset se encuentran mayormente vehiculos con un peso alto, tambien se puede notar que exiten pocos datos graficados, por lo que se deduce que la celda columna tiene gran cantidad de nulos, por lo que se puede descartar la columna

# %%
print('Datos Nulos')
df[colum].isna().value_counts()
# Out:
# Datos Nulos
# NG Vehicle Class
# True     68626
# False     1780
# Name: count, dtype: int64

# %% [markdown]
# ---
# 'LPG Primary' - Estaciones de carga compatibles con vehículos que utilizan Gas Licuado de Petróleo
# ---
# ---

# %%
colum = 'LPG Primary'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
print('Datos Nulos')
df[colum].isna().value_counts()
# Out:
# Datos Nulos
# LPG Primary
# True     68539
# False     1867
# Name: count, dtype: int64

# %% [markdown]
# mas de 68k datos dentro del dataset son nulos, es decir, son estaciones de carga que no ofrecen Gas Licuado de Petroleo, mientras que 1867 estaciones de carga ofertan este tipo de combustible

# %% [markdown]
# ---
# 'E85 Blender Pump'
# ---
# ---

# %%
colum = 'E85 Blender Pump'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# E85 Blender Pump
# False    2995
# True     1513
# Name: count, dtype: int64

# %%
print('Datos Nulos')
df[colum].isna().value_counts()
# Out:
# Datos Nulos
# E85 Blender Pump
# True     65898
# False     4508
# Name: count, dtype: int64

# %% [markdown]
# Existen mas de 1500 estaciones de carga que ofrecen E85 Blender Pump  etanol al 85% como combustible en el dataset y mas de 65k que no lo ofertan

# %% [markdown]
# ---
# 'EV Connector Types' - Tipos de conector de Vehiculos electricos
# ---
# ---

# %%
colum = 'EV Connector Types'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# EV Connector Types
# J1772                               47190
# CHADEMO J1772COMBO                   4357
# TESLA                                3892
# J1772 TESLA                          2834
# CHADEMO J1772 J1772COMBO             1061
# J1772COMBO                            519
# CHADEMO J1772                         331
# J1772 J1772COMBO                      134
# J1772 NEMA515                         122
# CHADEMO                               112
# J1772 NEMA520                          95
# J1772 NEMA1450                         23
# CHADEMO J1772 J1772COMBO TESLA          6
# CHADEMO J1772COMBO TESLA                2
# CHADEMO J1772 NEMA520 TESLA             1
# CHADEMO J1772 NEMA515                   1
# CHADEMO J1772COMBO NEMA520              1
# CHADEMO NEMA520                         1
# J1772COMBO NEMA520                      1
# J1772 NEMA515 NEMA520                   1
# CHADEMO J1772 NEMA520                   1
# NEMA1450 TESLA                          1
# ...

# %% [markdown]
# Los tipos de conectores para vehiculos electricos que se encuentran en la mayoria de las estaciones de carga son J1772 con mas de 47k datos , en segundo lugar CHADEMO J1772 con aprox 4.3k estaciones y en tercer lugar Tesla con 3.8k datos aproximadamente

# %% [markdown]
# ---
# Country - Pais donde se ecuentran las estaciones de Carga
# ---
# ---

# %%
colum = 'Country'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# Country
# US    61621
# CA     8785
# Name: count, dtype: int64

# %% [markdown]
# Se observa como en el dataset existen mayormente estaciones de carga en Estados Unidos

# %% [markdown]
# ---
# 'Access Days Time (French)'
# ---
# ---

# %%
colum = 'Access Days Time (French)'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:11: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
cont
# Out:
# Access Days Time (French)
# Accessible 24 heures par jour                                                                                             4036
# 24 heures par jour                                                                                                         762
# Accessible 24 heures par jour; réservé aux clients; rendez-vous à la réception pour avoir accès                            191
# Accessible 24 heures par jour; à l'usage des modèles Tesla seulement                                                       123
# Accessible 24 heures par jour; réservé aux clients                                                                         115
# 6:00-22:00 tous les jours                                                                                                   36
# Accessible 24 heures par jour; payer beaucoup                                                                               32
# ...

# %% [markdown]
# Esta columna tiene muchos datos que significan lo mismo pero escritos de forma completamente diferente, por lo que debe realizarle una limpieza, puesto que a observar la mayoria de las estaciones de carga son de 24 horas de servicio

# %% [markdown]
# ---
# 'BD Blends (French)
# ---
# ---

# %%
colum = 'BD Blends (French)'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# BD Blends (French)
# B100              1
# B100, B50, B20    1
# Name: count, dtype: int64

# %%
print('Datos Nulos')
df[colum].isna().value_counts()
# Out:
# Datos Nulos
# BD Blends (French)
# True     70404
# False        2
# Name: count, dtype: int64

# %% [markdown]
# Analizando esta columna se puede notar que la mayor parte de los datos son nulos, conviene eliminar columna

# %% [markdown]
# ---
# 'Groups With Access Code (French)'
# ---
# ---

# %%
colum = 'Groups With Access Code (French)'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# Groups With Access Code (French)
# Public                                                                             58045
# Privé                                                                               3849
# Public - Carte de crédit en tout temps                                              3629
# Public - Appeler à l'avance                                                         1776
# Privé - Réservé au gouvernement                                                      939
# PRÉVU - pas encore accessible (Public)                                               795
# Public - Carte de crédit après les heures d'ouverture                                539
# Public - Carte-clé en tout temps                                                     214
# TEMPORAIREMENT SUSPENDU (Public)                                                     144
# PRÉVU - pas encore accessible (Privé)                                                130
# ...

# %% [markdown]
# De igual forma esta columna tiene varios datos que corresponde o signnifican lo mismo, por lo que conviene realizar una limpieza y utilizar los datos, ya que son importantes.
# Con lo datos que se tienen se nota como la mayor cantidad de estaciones de craga son Publicas o abiertas a publico en general

# %% [markdown]
# ---
# 'Hydrogen Is Retail'
# ---
# ---

# %%
colum = 'Hydrogen Is Retail'
cont = graficar_conteo (colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# Hydrogen Is Retail
# True    117
# Name: count, dtype: int64

# %%
print('Datos Nulos')
df[colum].isna().value_counts()
# Out:
# Datos Nulos
# Hydrogen Is Retail
# True     70289
# False      117
# Name: count, dtype: int64

# %% [markdown]
# Esta columna determina si una estación de recarga de hidrógeno es accesible para el público en general o si es exclusiva para usuarios autorizados o privados

# %% [markdown]
# ---
# 'Access Code'
# ---
# ---

# %%
colum = 'Access Code'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# Access Code
# public     65325
# private     5081
# Name: count, dtype: int64

# %% [markdown]
# La mayoria de estaciones de carga son Publicas

# %% [markdown]
# ---
# 'Access Detail Code'
# ---
# ---

# %%
colum = 'Access Detail Code'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# Access Detail Code
# CREDIT_CARD_ALWAYS         3758
# CALL                       1800
# GOVERNMENT                  944
# CREDIT_CARD_AFTER_HOURS     550
# KEY_ALWAYS                  232
# FLEET                        80
# KEY_AFTER_HOURS              55
# LIMITED_HOURS                 3
# RESIDENTIAL                   1
# Name: count, dtype: int64

# %% [markdown]
# La columna 'Access Detail Code' indica si la estación de carga límitan el acceso

# %% [markdown]
# ---
# 'Federal Agency Code', código que identifica a una agencia gubernamental federal específica que está asociada con una estación de recarga
# ---
# ---

# %%
colum = 'Federal Agency Code'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# Federal Agency Code
# DON         200
# DOI         134
# DOE         126
# USMC         78
# DAF          69
# DA           58
# VA           58
# DOT          27
# NASA         24
# DOJ          24
# USDA         22
# DHS          20
# USPS         19
# EPA          15
# DEF          14
# HHS          14
# SI           12
# DOC           8
# DOD           8
# SSA           8
# USACE_CW      7
# GSA           5
# DTS           2
# DOS           1
# TRANS         1
# DOL           1
# Name: count, dtype: int64

# %% [markdown]
# La lista que se muestra, indica los codigos de accesos de una Agencia Federal ligada a una estación de carga , y la columna numérica, contiene el total de estaciones de caraga que posee esa Agencia Federal (indicada con codigo)

# %% [markdown]
# ---
# 'Facility Type', tipo de instalación o infraestructura que ofrece servicios de recarga o combustible
# ---
# ---

# %%
colum = 'Facility Type'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
cont
# Out:
# Facility Type
# CONVENIENCE_STORE            4951
# HOTEL                        3133
# CAR_DEALER                   2885
# MUNI_GOV                     1217
# SHOPPING_CENTER              1151
# OFFICE_BLDG                  1037
# GAS_STATION                   853
# UTILITY                       826
# FUEL_RESELLER                 797
# GROCERY                       667
# FED_GOV                       666
# STANDALONE_STATION            642
# PARKING_LOT                   636
# COLLEGE_CAMPUS                575
# RENTAL_CAR_RETURN             565
# SHOPPING_MALL                 541
# RESTAURANT                    487
# PAY_GARAGE                    484
# PARKING_GARAGE                428
# FLEET_GARAGE                  409
# INN                           369
# STATE_GOV                     325
# BREWERY_DISTILLERY_WINERY     323
# TRAVEL_CENTER                 287
# PARK                          262
# HOSPITAL                      258
# SCHOOL                        258
# ...

# %% [markdown]
# Esta columna indica si la estación de servicio se encuentra en alguna infraestructura o lugar en específico y la lista muestra los tipos de infraestructura y el conteo de las estaciones ubbicadas en ese tipo.
# Se puede observar que existen mayor cantidad de estaciones de carga de combustibles en tiendas de conveniencia, seguido las estaciones se aglomeran en hoteles, en tercer lugar estan los concesionarios de coches, despues los mini gobiernos, en quinto los centros de compras o supermercados, entre otros.

# %% [markdown]
# ---
# 'CNG Dispenser Num',  Número de dispensadores de Gas Natural Comprimido disponibles en la estación de servicio
# ---
# ---

# %%
colum = 'CNG Dispenser Num'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# CNG Dispenser Num
# 1.0      417
# 2.0      415
# 3.0       86
# 4.0       85
# 6.0        4
# 12.0       4
# 5.0        4
# 8.0        3
# 40.0       2
# 80.0       2
# 7.0        2
# 14.0       1
# 16.0       1
# 22.0       1
# 10.0       1
# 47.0       1
# 70.0       1
# 26.0       1
# 202.0      1
# 15.0       1
# 31.0       1
# 52.0       1
# 49.0       1
# 45.0       1
# 0.0        1
# 24.0       1
# Name: count, dtype: int64

# %% [markdown]
# Las estaciones con mayor numero de dispensadores de Gas Natural Comprimido, son con 1,2,3 y 4 dispensadores, en ese orden
#
# Sin embargo ecisten estaciones de carga con hasta 80 y 202 dispensadores de este tipo

# %% [markdown]
# ---
# 'CNG On-Site Renewable Source',  Indica si la estación de servicio tiene fuentes de energía renovables en el sitio para producir Gas Natural Comprimido y que tipo
# ---
# ---

# %%
colum = 'CNG On-Site Renewable Source'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# CNG On-Site Renewable Source
# NONE          695
# LANDFILL       14
# WASTEWATER      3
# SOLAR           3
# LIVESTOCK       1
# Name: count, dtype: int64

# %% [markdown]
# Se puede notar que son muy pocas las estaciones de servicio que obtienen el combustible Gas Natural Comprimido de una fuente renovable, estas son LANDFILL, WASTEWATER, SOLAR y LIVESTOCK

# %% [markdown]
# ---
# 'CNG Total Compression Capacity'  Indica la capacidad de compresión de Gas Natural Comprimido, es decir la capacidad de la estación para suministrar CNG
# ---
# ---

# %%
colum = 'CNG Total Compression Capacity'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
cont
# Out:
# CNG Total Compression Capacity
# 1400.0    44
# 1000.0    39
# 975.0     24
# 500.0     24
# 300.0     22
# 400.0     20
# 100.0     20
# 50.0      19
# 25.0      17
# 150.0     16
# 250.0     16
# 200.0     15
# 800.0     14
# 116.0     14
# 1200.0    12
# 700.0     10
# 600.0     10
# 350.0      9
# 900.0      9
# 75.0       8
# 1500.0     8
# 1100.0     8
# 1600.0     8
# 2800.0     8
# 1300.0     7
# 30.0       7
# 989.0      6
# 650.0      5
# 60.0       5
# 257.0      5
# Name: count, dtype: int64

# %% [markdown]
# La capacidad mayor de las estaciones es de 1400 con 44 estaciones de Gas Natural Comprimido, el rango va desde 25 hasta 2800

# %% [markdown]
# ---
# 'CNG Storage Capacity',  Capacidad de almacenamiento de Gas Natural Comprimido de la estación de servicio
# ---
# ---

# %%
colum = 'CNG Storage Capacity'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")

# %%
cont
# Out:
# CNG Storage Capacity
# 36000.0    46
# 33000.0    23
# 28125.0    12
# 72000.0    12
# 30000.0    11
# 60000.0    11
# 34713.0     8
# 37000.0     8
# 69426.0     7
# 66000.0     7
# 40000.0     5
# 0.0         4
# 87647.0     4
# 45600.0     4
# 37071.0     4
# 1000.0      3
# 18000.0     3
# 33400.0     3
# 48000.0     3
# 37500.0     3
# 18566.0     3
# 24714.0     3
# 63937.0     3
# 43823.0     3
# 56250.0     3
# 58000.0     3
# 4195.0      3
# 11121.0     3
# 5000.0      3
# 66728.0     2
# Name: count, dtype: int64

# %% [markdown]
# La mayor cantidad de almacenamiento de gas natural en las estaciones de servicio es de 87647 sin elbargo son pocas las estaciones qeu tienen esa capacidad.
# El almacenamiento comun es de 36000 unidades para almacenamiento y cuentan con esta característica 46 estaciones

# %% [markdown]
# ---
# 'LNG On-Site Renewable Source', Indica si se cuenta con una fuente de energía renovable en el sitio para producir Gas Natural Licuado (camiones y vehículos pesados)
# ---
# ---

# %%
colum = 'LNG On-Site Renewable Source'
cont = graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')

# %%
cont
# Out:
# LNG On-Site Renewable Source
# NONE    62
# Name: count, dtype: int64

# %%
df[colum].unique()
# Out:
# array([nan, 'NONE'], dtype=object)

# %% [markdown]
# Dentro del Dataset se tienen dos posibles valores para esta columna None y nan, en ambos casos se puede decir que no hay existencia de data, por lo que se puede eliminar del dataset para la carga de datos

# %% [markdown]
# ---
# 'E85 Other Ethanol Blends',  La estación cuenta con otras mezclas de etanol diferente a 85% etanol y resto gasolina
# ---
# ---

# %%
colum = 'E85 Other Ethanol Blends'
graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# E85 Other Ethanol Blends
# ["E15"]                                      1117
# ["E15", "E30-E35"]                            126
# ["E30-E35"]                                    83
# ["E40-Plus"]                                   26
# ["E15", "E20-E25", "E30-E35"]                  26
# ["E20-E25", "E30-E35"]                         17
# ["E20-E25"]                                    13
# ["E20-E25", "E30-E35", "E40-Plus"]             11
# ["E15", "E20-E25", "E30-E35", "E40-Plus"]      10
# ["E15", "E30-E35", "E40-Plus"]                  7
# ["E15", "E20-E25"]                              7
# ["E30-E35", "E40-Plus"]                         6
# ...

# %% [markdown]
# Esta columna indica si la estacion de carga cuenta con combustible de etanol diferente al 85% de concentración
#
# Se puede notar que los rangos con los que cuenta la estacion son :
# concentracion al 15%, concentración del 15 a 30 y para el tercer peldaño del 30 al 35%

# %% [markdown]
# ---
# 'EV Pricing',  Costo de carga de energía en vehículos eléctricos
# ---
# ---

# %%
colum = 'EV Pricing'
graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:11: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# EV Pricing
# Free                                                                                                         10377
# $0.28 per kWh; $0.26 per minute above 60 kW and $0.13 per minute at or below 60 kW                            1155
# FREE                                                                                                          1122
# ...

# %% [markdown]
# El grafico que se muestra anteriormente indica como gran cantidad de estaciones de carga ofrece combustible para vegiculos electricos de forma gratuita, por loq ue es un insigh muy importante en los datos y en el proyecto, por los beneficios que ofrece tanto ambiientales como económicos. de esta manera se pueden aumentar los ingresos por el servicio de transporte publico

# %% [markdown]
# ---
# 'EV Pricing (French)',  Costo de carga de energía en vehículos eléctricos n Frances
# ---
# ---

# %%
colum = 'EV Pricing (French)'
graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:11: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# EV Pricing (French)
# Gratuit                                                                              1499
# $0.44 par minute au-dessus de 60 kW et $0.22 par minute à 60 kW ou moins              123
# L2: 1,50 $ de l'heure; DC Fast: 15,00 $ de l'heure                                     62
# $1,50 par heure                                                                        45
# ...

# %% [markdown]
# ---
# 'LPG Nozzle Types',   Tipo de boquillas o mangueras para dispensar Gas Licuado de Petróleo
# ---
# ---

# %%
colum = 'LPG Nozzle Types'
graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# LPG Nozzle Types
# ["ACME"]                     1007
# ["QUICK_CONNECT", "ACME"]     511
# ["ACME", "QUICK_CONNECT"]     223
# ["QUICK_CONNECT"]              85
# Name: count, dtype: int64

# %% [markdown]
# Para Gas Licuado de Petroleo el tipo de conector ACME es mas comun en las estaciones de servicio

# %% [markdown]
# ---
# 'Hydrogen Pressures',  Presiones de Hidrógeno
# ---
# ---

# %%
colum = 'Hydrogen Pressures'
graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# Hydrogen Pressures
# ["700"]           71
# ["350", "700"]    45
# Name: count, dtype: int64

# %% [markdown]
# La mayor cantidad de etsaciones de carga tienen presiones de 700 para el combustible Gas Licuado de Petroleo

# %% [markdown]
# ---
# 'Hydrogen Standards',  Indica si la estación de servicio cumple con las normas o especificaciones de calidad y seguridad para dispensar hidrogeno
# ---
# ---

# %%
colum = 'Hydrogen Standards'
graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# Hydrogen Standards
# ["J2601"]      115
# ["J2601-2"]      1
# Name: count, dtype: int64

# %% [markdown]
# Son pocas las estaciones de carga dispensadoras de Hidrogeno que cuentan con el cumplimiento de normas, las normas son: J2601, J2601-2

# %% [markdown]
# ---
# 'CNG Fill Type Code',  Tipo de llenado de la estación de servicio de Gas Natural Comprimido
# ---
# ---

# %%
colum = 'CNG Fill Type Code'
graficar_conteo(colum)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# CNG Fill Type Code
# Q    1155
# T     248
# B     200
# Name: count, dtype: int64

# %% [markdown]
# Muestran las estacuiones de carga y el tipo de llenado con el que cuentan para el combustible Gas Natural Comprimido

# %% [markdown]
# ---
# 'CNG PSI',  Presión de dispensación de Gas Natural
# ---
# ---

# %%
graficar_conteo('CNG PSI')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# CNG PSI
# 3600         1126
# 3000 3600     232
# 3600.0        174
# 3000           61
# 3000.0          4
# Name: count, dtype: int64

# %% [markdown]
# El grafico muestra las diferentes presiones de llenado con las que estan equipadas las estaciones de carga para el Gas Natural como combustible

# %% [markdown]
# ---
# 'CNG Vehicle Class',  Clases de Vehículos que se atienden en la estación de servicio para proporcionar Gas Natural Comprimido (Ligeros, Medianos y Pesados)
# ---
# ---

# %%
graficar_conteo('CNG Vehicle Class')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# CNG Vehicle Class
# HD    1331
# MD     254
# LD      37
# Name: count, dtype: int64

# %% [markdown]
# La columna de datos tiene informacion sobre las estaciones de carga y los tipo de vehiculos que atiende respecto a su tamaño
# - HD significa "Heavy Duty" (Pesado) y se refiere a vehículos grandes o pesados, como camiones o autobuses.
# - MD significa "Medium Duty" (Medio) y se refiere a vehículos de tamaño mediano, como furgonetas o camionetas.
# - LD significa "Light Duty" (Ligero) y se refiere a vehículos pequeños o livianos, como automóviles o SUVs.

# %% [markdown]
# ---
# 'LNG Vehicle Class',  Clases de vehículos para dispensar Gas Natural Licuado (Vehiculos de manejo pesados)
# ---
# ---

# %%
graficar_conteo('LNG Vehicle Class')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# LNG Vehicle Class
# HD    158
# Name: count, dtype: int64

# %% [markdown]
# Se nota como existen una gran cantidad de valores nulos o nan en esta columna, por lo que no es buena idea considerarla, de igual forma, se puede observar como solo existe un tipo de dato en todo el dataset, lo que indica es que solo 158 estaciones de servicio son capaces de atender vehiculos pesados

# %% [markdown]
# ---
# 'EV On-Site Renewable Source',  Indica si la estación de carga de vehículos eléctricos (EV) utiliza una fuente de energía renovable generada en el mismo sitio para cargar los vehículos.
# ---
# ---

# %%
graficar_conteo('EV On-Site Renewable Source')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# EV On-Site Renewable Source
# SOLAR         252
# NONE           73
# WIND           27
# HYDRO          14
# WASTEWATER      3
# LANDFILL        1
# Name: count, dtype: int64

# %% [markdown]
# Esta columna aporta informacion de suma importancia pues to que indica de donde proviene la energia electrica que ofrecen como producto las estaciones de carga para vehiculos electricos.
#
# - SOLAR (252): Se refiere a la energía generada por paneles solares.
# - NONE (73): Indica que no hay una fuente de energía renovable en el sitio.
# - WIND (27): Se refiere a la energía generada por turbinas eólicas.
# - HYDRO (14): Se refiere a la energía generada por centrales hidroeléctricas.
# - WASTEWATER (3): Se refiere a la energía generada a partir del tratamiento de aguas residuales.
# - LANDFILL (1): Se refiere a la energía generada a partir de la quema de residuos en vertederos.
#
# El numero entre parentesis indica la cantidad de estaciones de carga en el dataset

# %% [markdown]
# ---
# 'Restricted Access'  Indica si la estación de servicio o carga tiene restricciones de acceso para ciertos usuarios o vehículos
# ---
# ---

# %%
graficar_conteo('Restricted Access')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13148\2852143966.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# Restricted Access
# False    52181
# True      1254
# Name: count, dtype: int64

# %% [markdown]
# La columna anterior indica si existen restricciones en las estaciones de servicio para ciertos vehiculos o determinados usuarios
# se puede observar que exiten mas de 1250 estaciones que si presentan restricciones

# %% [markdown]
# ---
# Estaciones de servicio en el estado de Nueva York
# ---
# ---

# %%
def graficar_conteo(colum):
    ret = df[colum].unique()
    if (len(df[colum].unique()) > 30):
        top_30 = df[colum].value_counts().nlargest(30)
        plt.figure(figsize=(10, 6))
        sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
        plt.xlabel(colum)
        plt.ylabel('Frecuencia')
        plt.title(f'Top 30 {colum} estaciones en Nueva York')
        plt.xticks(rotation=90) 
        plt.tight_layout()
        plt.show()
        return top_30
    else:
        plt.figure(figsize=(10, 6))
        sns.countplot(x=df[colum], palette='bright')
        plt.xlabel(colum)
        plt.ylabel('Frecuencia')
        plt.title(f'{colum} en Nueva York')
        plt.xticks(rotation=90) 
        plt.show()
        return df[colum].value_counts()

# %%
pd.reset_option('all')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\2786130087.py:1: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\2786130087.py:1: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')

# %%
df_estaciones_NY = df[df['State'] == 'NY']

# %%
df_estaciones_NY.shape
# Out:
# (3409, 65)

# %% [markdown]
# Se tienen 3409 estaciones de carga en Nueva York

# %%
df = df_estaciones_NY

# %%
graficar_conteo('EV Connector Types')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\284773742.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# EV Connector Types
# J1772                       2517
# J1772 TESLA                  309
# TESLA                        233
# CHADEMO J1772COMBO           125
# J1772COMBO                    16
# CHADEMO J1772 J1772COMBO      14
# CHADEMO J1772                  9
# J1772 J1772COMBO               7
# J1772 NEMA520                  3
# CHADEMO                        1
# CHADEMO J1772COMBO TESLA       1
# Name: count, dtype: int64

# %% [markdown]
# ---
# Precio de estaciones de carag en Nueva York (solo vehiculos electricos)
# ---
# ---

# %%
graficar_conteo('EV Pricing')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\284773742.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_30.index, y=top_30.values, palette="bright")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\284773742.py:11: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# EV Pricing
# Free                                                                                  632
# Level 2: $0.59 per kWh                                                                 99
# $0.28 per kWh; $0.26 per minute above 60 kW and $0.13 per minute at or below 60 kW     57
# FREE                                                                                   14
# ...

# %% [markdown]
# ---
# Tipo de red de carga para vehiculos electricos en Nueva York
# ---
# ---

# %%
graficar_conteo('EV Network')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\284773742.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# EV Network
# ChargePoint Network    1627
# Tesla Destination       472
# EV Connect              334
# Non-Networked           269
# LIVINGSTON              190
# Blink Network           103
# Tesla                    68
# FLO                      42
# Electrify America        34
# Greenlots                26
# eVgo Network             23
# Volta                    22
# SemaCharge Network       17
# OpConnect                 2
# SWTCH                     2
# POWERFLEX                 1
# AMPUP                     1
# EVGATEWAY                 1
# CHARGELAB                 1
# Name: count, dtype: int64

# %% [markdown]
# ---
# Estaciones de carga en Nueva York que utilizan energía renovable
# ---
# ---

# %%
graficar_conteo('EV On-Site Renewable Source')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\284773742.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# EV On-Site Renewable Source
# NONE     36
# SOLAR     2
# Name: count, dtype: int64

# %%
graficar_conteo('Owner Type Code')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18308\284773742.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[colum], palette='bright')
# Owner Type Code
# P     1307
# LG     132
# SG      48
# T       33
# FG      21
# J        2
# Name: count, dtype: int64

# %% [markdown]
# (T: transporte, P: Privado, LG: Gobierno local, SG: Gobierno estatal, FG: Gobierno Federal, J, Jurisdicción)
